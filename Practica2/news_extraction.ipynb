# %%
import feedparser
import pandas as pd
import numpy as np
import re
from datetime import datetime
import spacy

# %%
#Solo ejecutar la primera vez
corpus = pd.DataFrame(columns = ['Source','Title','Content','Section','URL','Date'])
corpus.head()
# Out:
# Empty DataFrame
# Columns: [Source, Title, Content, Section, URL, Date]
# Index: []

# %% [markdown]
# #### RSS de la Jornada

# %%
deportes_jornada = feedparser.parse('https://www.jornada.com.mx/rss/deportes.xml?v=1')
economia_jornada = feedparser.parse('https://www.jornada.com.mx/rss/economia.xml?v=1')
cultura_jornada = feedparser.parse('https://www.jornada.com.mx/rss/cultura.xml?v=1')
ciencia_jornada = feedparser.parse('https://www.jornada.com.mx/rss/ciencias.xml?v=1')

# %% [markdown]
# #### RSS de Expansión

# %%
tecnologia_expansion = feedparser.parse('https://expansion.mx/rss/tecnologia')
economia_expansion = feedparser.parse('https://expansion.mx/rss/economia')

# %%
def jornada (jornada_parser):
    # Crear una lista para almacenar los datos
    data_list = []

    for entry in jornada_parser.entries:

        # Extraer la sección a partir del enlace
        link = entry.title_detail.base
        match = re.search(r'/rss/(\w+)\.xml', link)
        entry_link = match.group(1) if match else 'Unknown'

        # Convertir la fecha de publicación al formato 01/01/2000
        fecha = deportes_jornada.entries[0].published
        fecha_obj = datetime.strptime(fecha, '%a, %d %b %Y %H:%M:%S GMT')
        fecha_format = fecha_obj.strftime('%d/%m/%Y')

                # Crear un diccionario con los datos
        row_data = {
            'Source': 'Jornada',
            'Title': entry.title,
            'Content': entry.summary,
            'Section': entry_link,
            'URL': entry.links[0].href,
            'Date': fecha_format
        }
        # Checamos que no exista esa noticia en el corpus
        if entry.title not in corpus['Title']:
            # Añadir el diccionario a la lista
            data_list.append(row_data)
        
    # Convertir la lista de diccionarios en un DataFrame
    df = pd.DataFrame(data_list, columns=['Source', 'Title', 'Content', 'Section', 'URL', 'Date'])
    
    return df

# %%
def expansion(Expansion_Parser):
    # Crear una lista para almacenar los datos
    data_list = []

    for entry in Expansion_Parser.entries:

        # Extraer la sección a partir del enlace
        link = entry.title_detail.base 
        match = re.search(r'rss\/(\w+)', link)
        entry_link = match.group(1) if match else 'Unknown'

        # Convertir la fecha de publicación al formato 01/01/2000
        fecha = entry.published
        fecha_obj = datetime.strptime(fecha, '%a, %d %b %Y %H:%M:%S GMT')
        fecha_format = fecha_obj.strftime('%d/%m/%Y')

        # Crear un diccionario con los datos
        row_data = {
            'Source': 'Expansion',
            'Title': entry.title,
            'Content': entry.summary,
            'Section': entry_link,
            'URL': entry.link,
            'Date': fecha_format
        }
        
        # Checamos que no exista esa noticia en el corpus
        if entry.title not in corpus['Title']:
            # Añadir el diccionario a la lista
            data_list.append(row_data)
    
    # Convertir la lista de diccionarios en un DataFrame
    df = pd.DataFrame(data_list, columns=['Source', 'Title', 'Content', 'Section', 'URL', 'Date'])
    
    return df

# %%
tecnologia_exp_df = expansion(tecnologia_expansion)
tecnologia_exp_df.head()
# Out:
#       Source                                              Title  \
# 0  Expansion  China avanza en su regulación para identificar...
# 1  Expansion  En medio de la crisis, la industria del gaming...
# 2  Expansion  Oracle construirá un centro hyperscale en Nuev...
# 3  Expansion  OpenAI planea reestructuración para ser una em...
# 4  Expansion  Meta empareja a OpenAI y Google en la carrera ...
#
#                                              Content     Section  \
# 0  En el país asiático están buscando implementar...  tecnologia
# 1  Los despidos han marcado el año de los videoju...  tecnologia
# 2  Samuel García, gobernador del estado, resaltó ...  tecnologia
# 3  Este cambio representaría una oportunidad para...  tecnologia
# 4  Durante el evento Meta Connect, Mark Zuckerber...  tecnologia
#
#                                                  URL        Date
# 0  https://expansion.mx/tecnologia/2024/09/27/nue...  27/09/2024
# 1  https://expansion.mx/tecnologia/2024/09/27/cri...  27/09/2024
# 2  https://expansion.mx/tecnologia/2024/09/26/ora...  26/09/2024
# 3  https://expansion.mx/tecnologia/2024/09/26/ope...  26/09/2024
# 4  https://expansion.mx/tecnologia/2024/09/26/met...  26/09/2024

# %%
economia_exp_df = expansion(economia_expansion)
economia_exp_df.head()
# Out:
#       Source                                              Title  \
# 0  Expansion  El gasto de consumidores en EU aumenta en agos...
# 1  Expansion  México registra déficit comercial de 4,868 mdd...
# 2  Expansion  Banxico mantendrá prudencia y cerrará el año c...
# 3  Expansion    Banxico ejecuta nuevo recorte a la tasa a 10.5%
# 4  Expansion  Janet Yellen se opone a reducir requisitos de ...
#
#                                              Content   Section  \
# 0  El gasto de los consumidores sigue apoyándose ...  economia
# 1  Las exportaciones mexicanos cayeron 1% y las i...  economia
# 2  Los analistas consideran que el mensaje del ba...  economia
# 3  El banco central hizo un segundo recorte conse...  economia
# 4  La secretaria del Tesoro de Estados Unidos pid...  economia
#
#                                                  URL        Date
# 0  https://expansion.mx/economia/2024/09/27/gasto...  27/09/2024
# 1  https://expansion.mx/economia/2024/09/27/balan...  27/09/2024
# 2  https://expansion.mx/economia/2024/09/27/banxi...  27/09/2024
# 3  https://expansion.mx/economia/2024/09/26/banxi...  26/09/2024
# 4  https://expansion.mx/economia/2024/09/26/yelle...  26/09/2024

# %%
ciencia_jor_df = jornada(ciencia_jornada)
ciencia_jor_df.head()
# Out:
# Empty DataFrame
# Columns: [Source, Title, Content, Section, URL, Date]
# Index: []

# %%
cultura_jor_df = jornada(cultura_jornada)
cultura_jor_df.head()
# Out:
# Empty DataFrame
# Columns: [Source, Title, Content, Section, URL, Date]
# Index: []

# %%
economia_jor_df = jornada(economia_jornada)
economia_jor_df.head()
# Out:
# Empty DataFrame
# Columns: [Source, Title, Content, Section, URL, Date]
# Index: []

# %%
deportes_jor_df = jornada(deportes_jornada)
deportes_jor_df.head()
# Out:
# Empty DataFrame
# Columns: [Source, Title, Content, Section, URL, Date]
# Index: []

# %%
corpus = pd.concat([tecnologia_exp_df,economia_exp_df, deportes_jor_df, economia_jor_df, ciencia_jor_df, cultura_jor_df], axis = 0)
corpus
# Out:
#        Source                                              Title  \
# 0   Expansion  China avanza en su regulación para identificar...
# 1   Expansion  En medio de la crisis, la industria del gaming...
# 2   Expansion  Oracle construirá un centro hyperscale en Nuev...
# 3   Expansion  OpenAI planea reestructuración para ser una em...
# 4   Expansion  Meta empareja a OpenAI y Google en la carrera ...
# ..        ...                                                ...
# 45  Expansion  Claudia Sheinbaum se reunirá con empresarios d...
# 46  Expansion  ¿Dónde hay mayor brecha salarial por género en...
# 47  Expansion  ¿Por qué es importante tener un seguro para tu...
# 48  Expansion  Peligra economía de México si Trump gana y cum...
# 49  Expansion  RappiCard alcanza los 5,107 millones de pesos ...
#
#                                               Content     Section  \
# 0   En el país asiático están buscando implementar...  tecnologia
# 1   Los despidos han marcado el año de los videoju...  tecnologia
# 2   Samuel García, gobernador del estado, resaltó ...  tecnologia
# 3   Este cambio representaría una oportunidad para...  tecnologia
# 4   Durante el evento Meta Connect, Mark Zuckerber...  tecnologia
# ..                                                ...         ...
# 45  En medio de voces empresariales que dicen que ...    economia
# 46  Banxico realizó un análisis de las brechas sal...    economia
# 47  Un seguro no solo cubre los daños materiales, ...    economia
# 48  La agencia calificadora anticipa que la econom...    economia
# 49  La empresa resalta que parte de su estrategia ...    economia
#
#                                                   URL        Date
# 0   https://expansion.mx/tecnologia/2024/09/27/nue...  27/09/2024
# 1   https://expansion.mx/tecnologia/2024/09/27/cri...  27/09/2024
# 2   https://expansion.mx/tecnologia/2024/09/26/ora...  26/09/2024
# 3   https://expansion.mx/tecnologia/2024/09/26/ope...  26/09/2024
# 4   https://expansion.mx/tecnologia/2024/09/26/met...  26/09/2024
# ..                                                ...         ...
# 45  https://expansion.mx/economia/2024/09/18/ebrar...  18/09/2024
# 46  https://expansion.mx/economia/2024/09/18/brech...  18/09/2024
# 47  https://expansion.mx/economia/2024/09/18/por-q...  18/09/2024
# 48  https://expansion.mx/economia/2024/09/18/econo...  18/09/2024
# 49  https://expansion.mx/economia/2024/09/18/rappi...  18/09/2024
#
# [96 rows x 6 columns]

# %%
corpus = corpus.reset_index(drop=True)
corpus.to_csv('corpus1.csv')

# %%
#Borrar duplicados
corpus.drop_duplicates(subset = 'Title', inplace = True)

# Convertir a minúsculas todas las columnas de tipo objeto (cadenas de texto)
corpus = corpus.apply(lambda x: x.str.lower() if x.dtype == "object" else x)

# %%
corpus
# Out:
#        Source                                              Title  \
# 0   expansion  china avanza en su regulación para identificar...
# 1   expansion  en medio de la crisis, la industria del gaming...
# 2   expansion  oracle construirá un centro hyperscale en nuev...
# 3   expansion  openai planea reestructuración para ser una em...
# 4   expansion  meta empareja a openai y google en la carrera ...
# ..        ...                                                ...
# 91  expansion  claudia sheinbaum se reunirá con empresarios d...
# 92  expansion  ¿dónde hay mayor brecha salarial por género en...
# 93  expansion  ¿por qué es importante tener un seguro para tu...
# 94  expansion  peligra economía de méxico si trump gana y cum...
# 95  expansion  rappicard alcanza los 5,107 millones de pesos ...
#
#                                               Content     Section  \
# 0   en el país asiático están buscando implementar...  tecnologia
# 1   los despidos han marcado el año de los videoju...  tecnologia
# 2   samuel garcía, gobernador del estado, resaltó ...  tecnologia
# 3   este cambio representaría una oportunidad para...  tecnologia
# 4   durante el evento meta connect, mark zuckerber...  tecnologia
# ..                                                ...         ...
# 91  en medio de voces empresariales que dicen que ...    economia
# 92  banxico realizó un análisis de las brechas sal...    economia
# 93  un seguro no solo cubre los daños materiales, ...    economia
# 94  la agencia calificadora anticipa que la econom...    economia
# 95  la empresa resalta que parte de su estrategia ...    economia
#
#                                                   URL        Date
# 0   https://expansion.mx/tecnologia/2024/09/27/nue...  27/09/2024
# 1   https://expansion.mx/tecnologia/2024/09/27/cri...  27/09/2024
# 2   https://expansion.mx/tecnologia/2024/09/26/ora...  26/09/2024
# 3   https://expansion.mx/tecnologia/2024/09/26/ope...  26/09/2024
# 4   https://expansion.mx/tecnologia/2024/09/26/met...  26/09/2024
# ..                                                ...         ...
# 91  https://expansion.mx/economia/2024/09/18/ebrar...  18/09/2024
# 92  https://expansion.mx/economia/2024/09/18/brech...  18/09/2024
# 93  https://expansion.mx/economia/2024/09/18/por-q...  18/09/2024
# 94  https://expansion.mx/economia/2024/09/18/econo...  18/09/2024
# 95  https://expansion.mx/economia/2024/09/18/rappi...  18/09/2024
#
# [96 rows x 6 columns]

# %%
# Cargar el modelo en español de spaCy
nlp = spacy.load('es_core_news_sm')

# Crear listas temporales para almacenar los resultados procesados
new_titles = []
new_contents = []

# Iterar sobre cada fila del DataFrame
for i, row in corpus.iterrows():
    doc_title = nlp(row['Title'])
    doc_content = nlp(row['Content'])
    

    # Procesar el título: reemplazar tokens por sus lemas, excluyendo artículos, conjunciones y pronombres
    new_title = " ".join([
        token.lemma_ if token.pos_ not in ['DET', 'CCONJ', 'SCONJ', 'PRON', 'ADP'] else '' for token in doc_title])
    # Eliminar espacios extra creados por tokens eliminados
    new_title = " ".join(new_title.split())
    new_titles.append(new_title)

    # Procesar el contenido: reemplazar tokens por sus lemas, excluyendo artículos, conjunciones, pronombres y stopwords
    new_content = " ".join([
        token.lemma_ if token.pos_ not in ['DET', 'CCONJ', 'SCONJ', 'PRON', 'ADP'] else '' for token in doc_content])

    # Eliminar espacios extra creados por tokens eliminados
    new_content = " ".join(new_content.split())

    new_contents.append(new_content)


# Asignar las listas modificadas al DataFrame
corpus['Title'] = new_titles
corpus['Content'] = new_contents

# %% [markdown]
# -articulo
# -conjuncion
# -pronombre

# %%
corpus
# Out:
#        Source                                              Title  \
# 0   expansion  chino avanzar regulación identificar contenido...
# 1   expansion  medio crisis , industria gaming buscar nuevo m...
# 2   expansion  oracle construir centro hyperscalar nuevo león...
# 3   expansion  openai planeo reestructuración ser empresa fin...
# 4   expansion            meta emparejar openai google carrera ia
# ..        ...                                                ...
# 91  expansion  claudia sheinbaum reunir empresario estados un...
# 92  expansion      ¿ haber mayor brecha salarial género méxico ?
# 93  expansion            ¿ ser importante tener seguro negocio ?
# 94  expansion  peligrar economía méxico trump gana cumplir ar...
# 95  expansion  rappicard alcanzar 5.107 millón pesos cartera ...
#
#                                               Content     Section  \
# 0   país asiático estar buscar implementar medida ...  tecnologia
# 1   despido haber marcar año videojuego , especial...  tecnologia
# 2   samuel garcía , gobernador estado , resaltar p...  tecnologia
# 3   cambio representar oportunidad startup consegu...  tecnologia
# 4   evento meta connect , zuckerberg presentar inn...  tecnologia
# ..                                                ...         ...
# 91  medio voz empresarial decir inversión haber de...    economia
# 92  banxico realizar análisis brecha salarial géne...    economia
# 93  seguro no solo cubrir daño material , también ...    economia
# 94  agencia calificadoro anticipar economía mexica...    economia
# 95  empresa resaltar partir estrategia ser ofrecer...    economia
#
#                                                   URL        Date
# 0   https://expansion.mx/tecnologia/2024/09/27/nue...  27/09/2024
# 1   https://expansion.mx/tecnologia/2024/09/27/cri...  27/09/2024
# 2   https://expansion.mx/tecnologia/2024/09/26/ora...  26/09/2024
# 3   https://expansion.mx/tecnologia/2024/09/26/ope...  26/09/2024
# 4   https://expansion.mx/tecnologia/2024/09/26/met...  26/09/2024
# ..                                                ...         ...
# 91  https://expansion.mx/economia/2024/09/18/ebrar...  18/09/2024
# 92  https://expansion.mx/economia/2024/09/18/brech...  18/09/2024
# 93  https://expansion.mx/economia/2024/09/18/por-q...  18/09/2024
# 94  https://expansion.mx/economia/2024/09/18/econo...  18/09/2024
# 95  https://expansion.mx/economia/2024/09/18/rappi...  18/09/2024
#
# [96 rows x 6 columns]

# %%
corpus = corpus.reset_index(drop=True)
corpus.to_csv('norm_corpus1.csv')

# %%
corpus
# Out:
#        Source                                              Title  \
# 0   expansion  chino avanzar regulación identificar contenido...
# 1   expansion  medio crisis , industria gaming buscar nuevo m...
# 2   expansion  oracle construir centro hyperscalar nuevo león...
# 3   expansion  openai planeo reestructuración ser empresa fin...
# 4   expansion            meta emparejar openai google carrera ia
# ..        ...                                                ...
# 91  expansion  claudia sheinbaum reunir empresario estados un...
# 92  expansion      ¿ haber mayor brecha salarial género méxico ?
# 93  expansion            ¿ ser importante tener seguro negocio ?
# 94  expansion  peligrar economía méxico trump gana cumplir ar...
# 95  expansion  rappicard alcanzar 5.107 millón pesos cartera ...
#
#                                               Content     Section  \
# 0   país asiático estar buscar implementar medida ...  tecnologia
# 1   despido haber marcar año videojuego , especial...  tecnologia
# 2   samuel garcía , gobernador estado , resaltar p...  tecnologia
# 3   cambio representar oportunidad startup consegu...  tecnologia
# 4   evento meta connect , zuckerberg presentar inn...  tecnologia
# ..                                                ...         ...
# 91  medio voz empresarial decir inversión haber de...    economia
# 92  banxico realizar análisis brecha salarial géne...    economia
# 93  seguro no solo cubrir daño material , también ...    economia
# 94  agencia calificadoro anticipar economía mexica...    economia
# 95  empresa resaltar partir estrategia ser ofrecer...    economia
#
#                                                   URL        Date
# 0   https://expansion.mx/tecnologia/2024/09/27/nue...  27/09/2024
# 1   https://expansion.mx/tecnologia/2024/09/27/cri...  27/09/2024
# 2   https://expansion.mx/tecnologia/2024/09/26/ora...  26/09/2024
# 3   https://expansion.mx/tecnologia/2024/09/26/ope...  26/09/2024
# 4   https://expansion.mx/tecnologia/2024/09/26/met...  26/09/2024
# ..                                                ...         ...
# 91  https://expansion.mx/economia/2024/09/18/ebrar...  18/09/2024
# 92  https://expansion.mx/economia/2024/09/18/brech...  18/09/2024
# 93  https://expansion.mx/economia/2024/09/18/por-q...  18/09/2024
# 94  https://expansion.mx/economia/2024/09/18/econo...  18/09/2024
# 95  https://expansion.mx/economia/2024/09/18/rappi...  18/09/2024
#
# [96 rows x 6 columns]
